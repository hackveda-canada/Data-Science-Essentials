# %% [markdown]
# <a href="https://colab.research.google.com/github/hackveda-canada/Data-Science-Essentials/blob/master/Personalization_with_WordCloud_sensitivity_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Gather process
# https://www.googleapis.com/customsearch/v1/?key=AIzaSyCATL1zbY0i3KDaIKfwz6t6peMyT_vA-0E&cx=012773643409177149611:giuhxzmolrc

# Take user input
keyword = input("Search a Keyword ")

# Connect to google.com and search the keyword
google_url = "https://www.googleapis.com/customsearch/v1/?key=AIzaSyCATL1zbY0i3KDaIKfwz6t6peMyT_vA-0E&cx=012773643409177149611:giuhxzmolrc"
search_request = google_url + "&q=" + keyword

# Send the request to server
import requests
response = requests.get(search_request)

# Show the response from Google
print(response.text)
# Out:
# Search a Keyword sensitivity analysis
# {
#  "kind": "customsearch#search",
#  "url": {
#   "type": "application/json",
#   "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#  },
#  "queries": {
#   "request": [
#    {
#     "title": "Google Custom Search - sensitivity analysis",
#     "totalResults": "105000000",
#     "searchTerms": "sensitivity analysis",
#     "count": 10,
#     "startIndex": 1,
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "012773643409177149611:giuhxzmolrc"
#    }
#   ],
#   "nextPage": [
#    {
#     "title": "Google Custom Search - sensitivity analysis",
#     "totalResults": "105000000",
#     "searchTerms": "sensitivity analysis",
#     "count": 10,
#     "startIndex": 11,
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "012773643409177149611:giuhxzmolrc"
#    }
#   ]
#  },
#  "context": {
#   "title": "*.google"
#  },
#  "searchInformation": {
#   "searchTime": 0.266881,
#   "formattedSearchTime": "0.27",
#   "totalResults": "105000000",
#   "formattedTotalResults": "105,000,000"
#  },
#  "items": [
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity analysis - Wikipedia",
#    "htmlTitle": "\u003cb\u003eSensitivity analysis\u003c/b\u003e - Wikipedia",
#    "link": "https://en.wikipedia.org/wiki/Sensitivity_analysis",
#    "displayLink": "en.wikipedia.org",
#    "snippet": "Sensitivity analysis is the study of how the uncertainty in the output of a \nmathematical model or system (numerical or otherwise) can be apportioned to \ndifferent ...",
#    "htmlSnippet": "\u003cb\u003eSensitivity analysis\u003c/b\u003e is the study of how the uncertainty in the output of a \u003cbr\u003e\nmathematical model or system (numerical or otherwise) can be apportioned to \u003cbr\u003e\ndifferent&nbsp;...",
#    "cacheId": "vrvSbdbLWAIJ",
#    "formattedUrl": "https://en.wikipedia.org/wiki/Sensitivity_analysis",
#    "htmlFormattedUrl": "https://en.wikipedia.org/wiki/\u003cb\u003eSensitivity\u003c/b\u003e_\u003cb\u003eanalysis\u003c/b\u003e",
#    "pagemap": {
#     "cse_thumbnail": [
#      {
#       "width": "253",
#       "height": "199",
#       "src": "https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcRsdy2dp5PNW8HD2ftgUDsqxY-ibDCzbyE8hT9_YZwTKOnsb3crBDPj3e6O"
#      }
#     ],
#     "metatags": [
#      {
#       "referrer": "origin"
#      }
#     ],
#     "cse_image": [
#      {
#       "src": "https://upload.wikimedia.org/wikipedia/en/thumb/0/01/Sensitivity_scheme.jpg/500px-Sensitivity_scheme.jpg"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analysis",
#    "htmlTitle": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e",
#    "link": "https://www.investopedia.com/terms/s/sensitivityanalysis.asp",
#    "displayLink": "www.investopedia.com",
#    "snippet": "Aug 4, 2018 ... Sensitivity analysis is a technique used to determine how different values of an \nindependent variable will affect a particular dependent variable ...",
#    "htmlSnippet": "Aug 4, 2018 \u003cb\u003e...\u003c/b\u003e \u003cb\u003eSensitivity analysis\u003c/b\u003e is a technique used to determine how different values of an \u003cbr\u003e\nindependent variable will affect a particular dependent variable&nbsp;...",
#    "cacheId": "o7vWfUzl0wAJ",
#    "formattedUrl": "https://www.investopedia.com/terms/s/sensitivityanalysis.asp",
#    "htmlFormattedUrl": "https://www.investopedia.com/terms/s/\u003cb\u003esensitivityanalysis\u003c/b\u003e.asp",
#    "pagemap": {
#     "cse_thumbnail": [
#      {
#       "width": "205",
#       "height": "136",
#       "src": "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQGzADK3AN_NDCuaWBfcMQGeIYx4EbE06ny7HIw7-8yCyd8gx5DRxZdj45b"
#      }
#     ],
#     "metatags": [
#      {
#       "msapplication-tilecolor": "#333e8b",
#       "msapplication-tileimage": "/static/1.16.0/icons/favicons/mstile-144x144.png",
#       "msapplication-square70x70logo": "/static/1.16.0/icons/favicons/mstile-70x70.png",
#       "msapplication-square150x150logo": "/static/1.16.0/icons/favicons/mstile-150x150.png",
#       "msapplication-square310x310logo": "/static/1.16.0/icons/favicons/mstile-310x310.png",
#       "msapplication-wide310x150logo": "/static/1.16.0/icons/favicons/mstile-310x150.png",
#       "viewport": "width=device-width, initial-scale=1.0",
#       "sailthru.tags": "financial-analysis",
#       "fb:app_id": "371867692868423",
#       "og:type": "article",
#       "og:site_name": "Investopedia",
#       "og:url": "https://www.investopedia.com/terms/s/sensitivityanalysis.asp",
#       "og:title": "Sensitivity Analysis",
#       "og:description": "Sensitivity analysis is a technique used to determine how different values of an independent variable will affect a particular dependent variable under a given set of assumptions.",
#       "og:image": "https://www.investopedia.com/thmb/xseE4gEcol55-cQMFxORZY-T2aU=/205x136/filters:fill(auto,1)/investing17-5bfc2b8fc9e77c00519aa64c.jpg",
#       "twitter:card": "summary",
#       "twitter:site": "@Investopedia",
#       "twitter:title": "Sensitivity Analysis",
#       "twitter:description": "Sensitivity analysis is a technique used to determine how different values of an independent variable will affect a particular dependent variable under a given set of assumptions.",
#       "twitter:image": "https://www.investopedia.com/thmb/xseE4gEcol55-cQMFxORZY-T2aU=/205x136/filters:fill(auto,1)/investing17-5bfc2b8fc9e77c00519aa64c.jpg",
#       "lotame:tax2": "inv_financial-analysis",
#       "lotame:tax1": "inv_investing",
#       "lotame:tax0": "inv",
#       "sailthru.author": "Will Kenton",
#       "sailthru.date": "2018-12-13T18:41:19.021Z",
#       "sailthru.image.thumb": "https://www.investopedia.com/thmb/zrpXn9ZpJ2hxiaOrHt07HQxBBo4=/255x165/filters:no_upscale()/investing17-5bfc2b8fc9e77c00519aa64c.jpg",
#       "sailthru.title": "Sensitivity Analysis",
#       "emailt1": "Investing",
#       "emailcontenttype": "TERMSC"
#      }
#     ],
#     "cse_image": [
#      {
#       "src": "https://www.investopedia.com/thmb/xseE4gEcol55-cQMFxORZY-T2aU=/205x136/filters:fill(auto,1)/investing17-5bfc2b8fc9e77c00519aa64c.jpg"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Overview of Sensitivity Analysis - What is Sensitivity Analysis",
#    "htmlTitle": "Overview of \u003cb\u003eSensitivity Analysis\u003c/b\u003e - What is \u003cb\u003eSensitivity Analysis\u003c/b\u003e",
#    "link": "https://corporatefinanceinstitute.com/resources/knowledge/modeling/what-is-sensitivity-analysis/",
#    "displayLink": "corporatefinanceinstitute.com",
#    "snippet": "Sensitivity Analysis is a tool used in financial modeling to analyze how the \ndifferent values for a set of independent variables affect a dependent variable \nunder ...",
#    "htmlSnippet": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e is a tool used in financial modeling to analyze how the \u003cbr\u003e\ndifferent values for a set of independent variables affect a dependent variable \u003cbr\u003e\nunder&nbsp;...",
#    "cacheId": "tQrhBF1hA-IJ",
#    "formattedUrl": "https://corporatefinanceinstitute.com/.../what-is-sensitivity-analysis/",
#    "htmlFormattedUrl": "https://corporatefinanceinstitute.com/.../what-is-\u003cb\u003esensitivity\u003c/b\u003e-\u003cb\u003eanalysis\u003c/b\u003e/",
#    "pagemap": {
#     "cse_thumbnail": [
#      {
#       "width": "246",
#       "height": "205",
#       "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjzmf1_kEYKDtKBecsCe5mR-4IQS83UjwKNdDQEabyjmoQLxEoL3uqMv1m"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1",
#       "og:locale": "en_US",
#       "og:type": "article",
#       "og:title": "Overview of Sensitivity Analysis - What is Sensitivity Analysis",
#       "og:description": "Sensitivity Analysis is a tool used in financial modeling to analyze how the different values for a set of independent variables affect a dependent variable under certain specific conditions. Sensitivity Analysis is performed in Excel to asses risks, measure potential outcomes, and plan for an uncertain future",
#       "og:url": "https://corporatefinanceinstitute.com/resources/knowledge/modeling/what-is-sensitivity-analysis/",
#       "og:site_name": "Corporate Finance Institute",
#       "article:publisher": "https://www.facebook.com/corporatefinanceinstitute.cfi/",
#       "og:image": "https://cdn.corporatefinanceinstitute.com/assets/sensitivity-analysis.png",
#       "og:image:secure_url": "https://cdn.corporatefinanceinstitute.com/assets/sensitivity-analysis.png",
#       "twitter:card": "summary",
#       "twitter:description": "Sensitivity Analysis is a tool used in financial modeling to analyze how the different values for a set of independent variables affect a dependent variable under certain specific conditions. Sensitivity Analysis is performed in Excel to asses risks, measure potential outcomes, and plan for an uncertain future",
#       "twitter:title": "Overview of Sensitivity Analysis - What is Sensitivity Analysis",
#       "twitter:site": "@CFI_education",
#       "twitter:image": "https://cdn.corporatefinanceinstitute.com/assets/sensitivity-analysis.png",
#       "twitter:creator": "@CFI_education",
#       "msapplication-tileimage": "https://cdn.corporatefinanceinstitute.com/assets/cropped-cfi-financial-modeling-logo-270x270.png",
#       "position": "1"
#      }
#     ],
#     "cse_image": [
#      {
#       "src": "https://cdn.corporatefinanceinstitute.com/assets/sensitivity-analysis.png"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analysis: Meaning, Uses, Methods of measurement",
#    "htmlTitle": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e: Meaning, Uses, Methods of measurement",
#    "link": "https://www.edupristine.com/blog/all-about-sensitivity-analysis",
#    "displayLink": "www.edupristine.com",
#    "snippet": "Mar 29, 2018 ... Find all the information about sensitivity analysis from meaning, uses, to methods \nof measurement, parameters while carrying sensitivity ...",
#    "htmlSnippet": "Mar 29, 2018 \u003cb\u003e...\u003c/b\u003e Find all the information about \u003cb\u003esensitivity analysis\u003c/b\u003e from meaning, uses, to methods \u003cbr\u003e\nof measurement, parameters while carrying sensitivity&nbsp;...",
#    "cacheId": "OsN42wi5KJQJ",
#    "formattedUrl": "https://www.edupristine.com/blog/all-about-sensitivity-analysis",
#    "htmlFormattedUrl": "https://www.edupristine.com/blog/all-about-\u003cb\u003esensitivity\u003c/b\u003e-\u003cb\u003eanalysis\u003c/b\u003e",
#    "pagemap": {
#     "cse_thumbnail": [
#      {
#       "width": "310",
#       "height": "162",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQpE8h1bsd8kiRuoHzrvqiDKr3P59j1CzadWHErF_0p2_dgeK98uxyvz-oU"
#      }
#     ],
#     "metatags": [
#      {
#       "fb:pages": "140534702673670",
#       "p:domain_verify": "8a72717f2edb95f79b6a1a1baa7afcb2",
#       "viewport": "width=device-width, initial-scale=1.0",
#       "og:locale": "en_US",
#       "og:type": "article",
#       "og:title": "Sensitivity Analysis: Meaning, Uses, Methods of measurement",
#       "og:description": "Find all the information about sensitivity analysis from meaning, uses, to methods of measurement, parameters while carrying sensitivity analysis and much more.",
#       "og:site_name": "EduPristine",
#       "article:tag": "how to do sensitivity analysis",
#       "article:section": "Financial Modeling",
#       "article:published_time": "2018-03-29T18:10:30+00:00",
#       "article:modified_time": "2018-10-11T18:09:55+00:00",
#       "og:updated_time": "2018-10-11T18:09:55+00:00",
#       "og:image": "//content.edupristine.com/images/blogs/analysis131.png",
#       "twitter:card": "summary",
#       "twitter:description": "Find all the information about sensitivity analysis from meaning, uses, to methods of measurement, parameters while carrying sensitivity analysis and much more.",
#       "twitter:title": "Sensitivity Analysis: Meaning, Uses, Methods of measurement",
#       "twitter:image": "//content.edupristine.com/images/blogs/analysis131.png",
#       "msapplication-tileimage": "https://static.edupristine.com/wp-content/uploads/2018/05/favicon.png",
#       "position": "1"
#      }
#     ],
#     "cse_image": [
#      {
#       "src": "https://content.edupristine.com/images/blogs/analysis131.png"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analysis (Business Forecasting) - YouTube",
#    "htmlTitle": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e (Business Forecasting) - YouTube",
#    "link": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#    "displayLink": "www.youtube.com",
#    "snippet": "Apr 14, 2018 ... This short revision video introduces and illustrates the concept of sensitivity \nanalysis. Sensitivity analysis is a technique which allows the ...",
#    "htmlSnippet": "Apr 14, 2018 \u003cb\u003e...\u003c/b\u003e This short revision video introduces and illustrates the concept of \u003cb\u003esensitivity\u003c/b\u003e \u003cbr\u003e\n\u003cb\u003eanalysis\u003c/b\u003e. \u003cb\u003eSensitivity analysis\u003c/b\u003e is a technique which allows the&nbsp;...",
#    "cacheId": "xIPpjC_4wskJ",
#    "formattedUrl": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#    "htmlFormattedUrl": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#    "pagemap": {
#     "cse_thumbnail": [
#      {
#       "width": "300",
#       "height": "168",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTZg4t7O0cAj2-sAovEcCWYCNrRETjrXCyqE-1Y3_5McEXq-YW_Dtwb7V8"
#      }
#     ],
#     "metatags": [
#      {
#       "title": "Sensitivity Analysis (Business Forecasting)",
#       "theme-color": "#ff0000",
#       "og:site_name": "YouTube",
#       "og:url": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#       "og:title": "Sensitivity Analysis (Business Forecasting)",
#       "og:image": "https://i.ytimg.com/vi/56-iiZEjqnU/maxresdefault.jpg",
#       "og:description": "This short revision video introduces and illustrates the concept of sensitivity analysis. Sensitivity analysis is a technique which allows the analysis of ch...",
#       "al:ios:app_store_id": "544007664",
#       "al:ios:app_name": "YouTube",
#       "al:ios:url": "vnd.youtube://www.youtube.com/watch?v=56-iiZEjqnU&feature=applinks",
#       "al:android:url": "vnd.youtube://www.youtube.com/watch?v=56-iiZEjqnU&feature=applinks",
#       "al:android:app_name": "YouTube",
#       "al:android:package": "com.google.android.youtube",
#       "al:web:url": "https://www.youtube.com/watch?v=56-iiZEjqnU&feature=applinks",
#       "og:type": "video.other",
#       "og:video:url": "https://www.youtube.com/embed/56-iiZEjqnU",
#       "og:video:secure_url": "https://www.youtube.com/embed/56-iiZEjqnU",
#       "og:video:type": "text/html",
#       "og:video:width": "1280",
#       "og:video:height": "720",
#       "og:video:tag": "sensitivity analysis",
#       "fb:app_id": "87741124305",
#       "twitter:card": "player",
#       "twitter:site": "@youtube",
#       "twitter:url": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#       "twitter:title": "Sensitivity Analysis (Business Forecasting)",
#       "twitter:description": "This short revision video introduces and illustrates the concept of sensitivity analysis. Sensitivity analysis is a technique which allows the analysis of ch...",
#       "twitter:image": "https://i.ytimg.com/vi/56-iiZEjqnU/maxresdefault.jpg",
#       "twitter:app:name:iphone": "YouTube",
#       "twitter:app:id:iphone": "544007664",
#       "twitter:app:name:ipad": "YouTube"
#      }
#     ],
#     "videoobject": [
#      {
#       "url": "https://www.youtube.com/watch?v=56-iiZEjqnU",
#       "name": "Sensitivity Analysis (Business Forecasting)",
#       "description": "This short revision video introduces and illustrates the concept of sensitivity analysis. Sensitivity analysis is a technique which allows the analysis of ch...",
#       "paid": "False",
#       "channelid": "UCe83jLdZ3PuqVwAHe6B3U2A",
#       "videoid": "56-iiZEjqnU",
#       "duration": "PT7M53S",
#       "unlisted": "False",
#       "thumbnailurl": "https://i.ytimg.com/vi/56-iiZEjqnU/maxresdefault.jpg",
#       "embedurl": "https://www.youtube.com/embed/56-iiZEjqnU",
#       "playertype": "HTML5 Flash",
#       "width": "1280",
#       "height": "720",
#       "isfamilyfriendly": "True",
#       "regionsallowed": "AD,AE,AF,AG,AI,AL,AM,AO,AQ,AR,AS,AT,AU,AW,AX,AZ,BA,BB,BD,BE,BF,BG,BH,BI,BJ,BL,BM,BN,BO,BQ,BR,BS,BT,BV,BW,BY,BZ,CA,CC,CD,CF,CG,CH,CI,CK,CL,CM,CN,CO,CR,CU,CV,CW,CX,CY,CZ,DE,DJ,DK,DM,DO,DZ,EC,EE,EG,EH...",
#       "interactioncount": "17886",
#       "datepublished": "2018-04-14",
#       "genre": "Education"
#      }
#     ],
#     "imageobject": [
#      {
#       "url": "https://i.ytimg.com/vi/56-iiZEjqnU/maxresdefault.jpg",
#       "width": "1280",
#       "height": "720"
#      }
#     ],
#     "person": [
#      {
#       "url": "http://www.youtube.com/channel/UCe83jLdZ3PuqVwAHe6B3U2A"
#      },
#      {
#       "url": "https://plus.google.com/111096761807997993184"
#      }
#     ],
#     "cse_image": [
#      {
#       "src": "https://i.ytimg.com/vi/56-iiZEjqnU/maxresdefault.jpg"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analysis - an overview | ScienceDirect Topics",
#    "htmlTitle": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e - an overview | ScienceDirect Topics",
#    "link": "https://www.sciencedirect.com/topics/medicine-and-dentistry/sensitivity-analysis",
#    "displayLink": "www.sciencedirect.com",
#    "snippet": "Sensitivity analysis for the ABM is to study how the variation in the output of a \nsystem can be apportioned to different input parameters [86]. In other words ...",
#    "htmlSnippet": "\u003cb\u003eSensitivity analysis\u003c/b\u003e for the ABM is to study how the variation in the output of a \u003cbr\u003e\nsystem can be apportioned to different input parameters [86]. In other words&nbsp;...",
#    "formattedUrl": "https://www.sciencedirect.com/topics/medicine-and.../sensitivity-analysis",
#    "htmlFormattedUrl": "https://www.sciencedirect.com/topics/medicine-and.../\u003cb\u003esensitivity\u003c/b\u003e-\u003cb\u003eanalysis\u003c/b\u003e",
#    "pagemap": {
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1",
#       "sdtech": "Proudly brought to you by the SD Technology team in London, Dayton, and Amsterdam"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Local Sensitivity Analysis (Automatic Differentiation ...",
#    "htmlTitle": "Local \u003cb\u003eSensitivity Analysis\u003c/b\u003e (Automatic Differentiation ...",
#    "link": "https://docs.juliadiffeq.org/latest/analysis/sensitivity.html",
#    "displayLink": "docs.juliadiffeq.org",
#    "snippet": "Sensitivity analysis for ODE models is provided by the DiffEq suite. The model \nsensitivities are the derivatives of the solution with respect to the parameters.",
#    "htmlSnippet": "\u003cb\u003eSensitivity analysis\u003c/b\u003e for ODE models is provided by the DiffEq suite. The model \u003cbr\u003e\nsensitivities are the derivatives of the solution with respect to the parameters.",
#    "cacheId": "zHYwSR9B9MYJ",
#    "formattedUrl": "https://docs.juliadiffeq.org/latest/analysis/sensitivity.html",
#    "htmlFormattedUrl": "https://docs.juliadiffeq.org/latest/\u003cb\u003eanalysis\u003c/b\u003e/\u003cb\u003esensitivity\u003c/b\u003e.html",
#    "pagemap": {
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1.0"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analysis - an overview | ScienceDirect Topics",
#    "htmlTitle": "\u003cb\u003eSensitivity Analysis\u003c/b\u003e - an overview | ScienceDirect Topics",
#    "link": "https://www.sciencedirect.com/topics/earth-and-planetary-sciences/sensitivity-analysis",
#    "displayLink": "www.sciencedirect.com",
#    "snippet": "Sensitivity analysis of all the parameters is carried out. It is the fundamental step \nbefore calibration. Sensitivity analysis attempts to provide a measure of the ...",
#    "htmlSnippet": "\u003cb\u003eSensitivity analysis\u003c/b\u003e of all the parameters is carried out. It is the fundamental step \u003cbr\u003e\nbefore calibration. \u003cb\u003eSensitivity analysis\u003c/b\u003e attempts to provide a measure of the&nbsp;...",
#    "formattedUrl": "https://www.sciencedirect.com/topics/earth-and.../sensitivity-analysis",
#    "htmlFormattedUrl": "https://www.sciencedirect.com/topics/earth-and.../\u003cb\u003esensitivity\u003c/b\u003e-\u003cb\u003eanalysis\u003c/b\u003e",
#    "pagemap": {
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1",
#       "sdtech": "Proudly brought to you by the SD Technology team in London, Dayton, and Amsterdam"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Sensitivity Analyses for Robust Causal Inference from Mendelian ...",
#    "htmlTitle": "\u003cb\u003eSensitivity Analyses\u003c/b\u003e for Robust Causal Inference from Mendelian ...",
#    "link": "https://www.ncbi.nlm.nih.gov/pubmed/27749700",
#    "displayLink": "www.ncbi.nlm.nih.gov",
#    "snippet": "Epidemiology. 2017 Jan;28(1):30-42. Sensitivity Analyses for Robust Causal \nInference from Mendelian Randomization Analyses with Multiple Genetic \nVariants.",
#    "htmlSnippet": "Epidemiology. 2017 Jan;28(1):30-42. \u003cb\u003eSensitivity Analyses\u003c/b\u003e for Robust Causal \u003cbr\u003e\nInference from Mendelian Randomization Analyses with Multiple Genetic \u003cbr\u003e\nVariants.",
#    "formattedUrl": "https://www.ncbi.nlm.nih.gov/pubmed/27749700",
#    "htmlFormattedUrl": "https://www.ncbi.nlm.nih.gov/pubmed/27749700",
#    "pagemap": {
#     "metatags": [
#      {
#       "citation_title": "Sensitivity Analyses for Robust Causal Inference from Mendelian Randomization Analyses with Multiple Genetic Variants.",
#       "citation_authors": "Burgess S; Bowden J; Fall T; Ingelsson E; Thompson SG",
#       "citation_date": "01/2017",
#       "citation_publisher": "Epidemiology",
#       "citation_journal_title": "Epidemiology (Cambridge, Mass.)",
#       "citation_pmid": "27749700",
#       "citation_abstract_html_url": "https://www.ncbi.nlm.nih.gov/pubmed/27749700",
#       "citation_volume": "28",
#       "citation_issue": "1",
#       "citation_firstpage": "30",
#       "citation_doi": "10.1097/EDE.0000000000000559",
#       "citation_issn": "1531-5487"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "A tutorial on sensitivity analyses in clinical trials: the what, why ...",
#    "htmlTitle": "A tutorial on \u003cb\u003esensitivity analyses\u003c/b\u003e in clinical trials: the what, why ...",
#    "link": "https://bmcmedresmethodol.biomedcentral.com/articles/10.1186/1471-2288-13-92",
#    "displayLink": "bmcmedresmethodol.biomedcentral.com",
#    "snippet": "Jul 16, 2013 ... Sensitivity analyses play a crucial role in assessing the robustness of the findings \nor conclusions based on primary analyses of data in clinical ...",
#    "htmlSnippet": "Jul 16, 2013 \u003cb\u003e...\u003c/b\u003e \u003cb\u003eSensitivity analyses\u003c/b\u003e play a crucial role in assessing the robustness of the findings \u003cbr\u003e\nor conclusions based on primary analyses of data in clinical&nbsp;...",
#    "cacheId": "sYmqCwFaCmIJ",
#    "formattedUrl": "https://bmcmedresmethodol.biomedcentral.com/.../1471-2288-13-92",
#    "htmlFormattedUrl": "https://bmcmedresmethodol.biomedcentral.com/.../1471-2288-13-92",
#    "pagemap": {
#     "metatags": [
#      {
#       "citation_abstract": "Sensitivity analyses play a crucial role in assessing the robustness of the findings or conclusions based on primary analyses of data in clinical trials. They are a critical way to assess the impact, effect or influence of key assumptions or variations—such as different methods of analysis, definitions of outcomes, protocol deviations, missing data, and outliers—on the overall conclusions of a study. The current paper is the second in a series of tutorial-type manuscripts intended to discuss and clarify aspects related to key methodological issues in the design and analysis of clinical trials. In this paper we will provide a detailed exploration of the key aspects of sensitivity analyses including: 1) what sensitivity analyses are, why they are needed, and how often they are used in practice; 2) the different types of sensitivity analyses that one can do, with examples from the literature; 3) some frequently asked questions about sensitivity analyses; and 4) some suggestions on how to report the results o",
#       "journal_id": "12874",
#       "dc.title": "A tutorial on sensitivity analyses in clinical trials: the what, why, when and how",
#       "dc.source": "BMC Medical Research Methodology 2013 13:1",
#       "dc.format": "text/html",
#       "dc.publisher": "BioMed Central",
#       "dc.date": "2013-07-16",
#       "dc.type": "Letter",
#       "dc.language": "En",
#       "dc.copyright": "2013 Thabane et al.; licensee BioMed Central Ltd.",
#       "dc.rights": "http://creativecommons.org/licenses/by/2.0",
#       "dc.rightsagent": "reprints@biomedcentral.com",
#       "dc.description": "Sensitivity analyses play a crucial role in assessing the robustness of the findings or conclusions based on primary analyses of data in clinical trials. They are a critical way to assess the impact, effect or influence of key assumptions or variations—such as different methods of analysis, definitions of outcomes, protocol deviations, missing data, and outliers—on the overall conclusions of a study. The current paper is the second in a series of tutorial-type manuscripts intended to discuss and clarify aspects related to key methodological issues in the design and analysis of clinical trials. In this paper we will provide a detailed exploration of the key aspects of sensitivity analyses including: 1) what sensitivity analyses are, why they are needed, and how often they are used in practice; 2) the different types of sensitivity analyses that one can do, with examples from the literature; 3) some frequently asked questions about sensitivity analyses; and 4) some suggestions on how to report the results o",
#       "prism.issn": "1471-2288",
#       "prism.publicationname": "BMC Medical Research Methodology",
#       "prism.publicationdate": "2013-07-16",
#       "prism.volume": "13",
#       "prism.number": "1",
#       "prism.section": "Letter",
#       "prism.startingpage": "92",
#       "prism.copyright": "2013 Thabane et al.; licensee BioMed Central Ltd.",
#       "prism.rightsagent": "reprints@biomedcentral.com",
#       "prism.url": "https://bmcmedresmethodol.biomedcentral.com/articles/10.1186/1471-2288-13-92",
#       "prism.doi": "doi:10.1186/1471-2288-13-92",
#       "citation_pdf_url": "https://bmcmedresmethodol.biomedcentral.com/track/pdf/10.1186/1471-2288-13-92",
#       "citation_fulltext_html_url": "https://bmcmedresmethodol.biomedcentral.com/articles/10.1186/1471-2288-13-92",
#       "citation_journal_title": "BMC Medical Research Methodology",
#       "citation_publisher": "BioMed Central",
#       "citation_issn": "1471-2288",
#       "citation_title": "A tutorial on sensitivity analyses in clinical trials: the what, why, when and how",
#       "citation_volume": "13",
#       "citation_issue": "1",
#       "citation_publication_date": "2013/12",
#       "citation_online_date": "2013/07/16",
#       "citation_firstpage": "92",
#       "citation_article_type": "Commentary",
#       "dc.identifier": "doi:10.1186/1471-2288-13-92",
#       "doi": "10.1186/1471-2288-13-92",
#       "citation_doi": "10.1186/1471-2288-13-92",
#       "dc.creator": "Lehana Thabane"
#      }
#     ],
#     "organization": [
#      {
#       "url": "https://www.biomedcentral.com/",
#       "logo": "https://bmcmedresmethodol.biomedcentral.com/static/images/bmc/logos/logo-bmc-white-series-1da6525f4e.svg"
#      }
#     ],
#     "scholarlyarticle": [
#      {
#       "headline": "A tutorial on sensitivity analyses in clinical trials: the what, why, when and how",
#       "ispartof": "13",
#       "sameas": "https://doi.org/10.1186/1471-2288-13-92",
#       "datepublished": "16 July 2013",
#       "about": "Sensitivity analysis"
#      },
#      {
#       "headline": "Thabane L, Ma J, Chu R, Cheng J, Ismaila A, Rios LP, Robson R, Thabane M, Giangregorio L, Goldsmith CH: A tutorial on pilot studies: the what, why and how. BMC Med Res Methodol. 2010, 10: 1-10.1186..."
#      },
#      {
#       "headline": "Schneeweiss S: Sensitivity analysis and external adjustment for unmeasured confounders in epidemiologic database studies of therapeutics. Pharmacoepidemiol Drug Saf. 2006, 15 (5): 291-303...."
#      },
#      {
#       "headline": "Viel JF, Pobel D, Carre A: Incidence of leukaemia in young people around the La Hague nuclear waste reprocessing plant: a sensitivity analysis. Stat Med. 1995, 14 (21–22): 2459-2472."
#      },
#      {
#       "headline": "Goldsmith CH, Gafni A, Drummond MF, Torrance GW, Stoddart GL: Sensitivity Analysis and Experimental Design: The Case of Economic Evaluation of Health Care Programmes. Proceedings of the Third..."
#      },
#      {
#       "headline": "Saltelli A, Tarantola S, Campolongo F, Ratto M: Sensitivity Analysis in Practice: A Guide to Assessing Scientific Models. 2004, New York, NY: Willey"
#      },
#      {
#       "headline": "Saltelli A, Ratto M, Andres T, Campolongo F, Cariboni J, Gatelli D, Saisana M, Tarantola S: Global Sensitivity Analysis: The Primer. 2008, New York, NY: Wiley-Interscience"
#      },
#      {
#       "headline": "Hunink MGM, Glasziou PP, Siegel JE, Weeks JC, Pliskin JS, Elstein AS, Weinstein MC: Decision Making in Health and Medicine: Integrating Evidence and Values. 2001, Cambridge: Cambridge University Press"
#      },
#      {
#       "headline": "USFDA: International Conference on Harmonisation; Guidance on Statistical Principles for Clinical Trials. Guideline E9. Statistical principles for clinical trials. Federal Register, 16 September..."
#      },
#      {
#       "headline": "NICE: Guide to the methods of technology appraisal. [http://www.nice.org.uk/media/b52/a7/tamethodsguideupdatedjune2008.pdf],"
#      },
#      {
#       "headline": "Ma J, Thabane L, Kaczorowski J, Chambers L, Dolovich L, Karwalajtys T, Levitt C: Comparison of Bayesian and classical methods in the analysis of cluster randomized controlled trials with a..."
#      },
#      {
#       "headline": "Peters TJ, Richards SH, Bankhead CR, Ades AE, Sterne JA: Comparison of methods for analysing cluster randomized trials: an example involving a factorial design. Int J Epidemiol. 2003, 32 (5):..."
#      },
#      {
#       "headline": "Chu R, Thabane L, Ma J, Holbrook A, Pullenayegum E, Devereaux PJ: Comparing methods to estimate treatment effects on a continuous outcome in multicentre randomized controlled trials: a simulation..."
#      },
#      {
#       "headline": "Kleinbaum DG, Klein M: Survival Analysis – A-Self Learning Text. 2012, Springer, 3"
#      },
#      {
#       "headline": "Barnett V, Lewis T: Outliers in Statistical Data. 1994, John Wiley & Sons, 3"
#      },
#      {
#       "headline": "Grubbs FE: Procedures for detecting outlying observations in samples. Technometrics. 1969, 11: 1-21. 10.1080/00401706.1969.10490657."
#      },
#      {
#       "headline": "Thabane L, Akhtar-Danesh N: Guidelines for reporting descriptive statistics in health research. Nurse Res. 2008, 15 (2): 72-81."
#      },
#      {
#       "headline": "Williams NH, Edwards RT, Linck P, Muntz R, Hibbs R, Wilkinson C, Russell I, Russell D, Hounsome B: Cost-utility analysis of osteopathy in primary care: results from a pragmatic randomized controlle..."
#      },
#      {
#       "headline": "Zetta S, Smith K, Jones M, Allcoat P, Sullivan F: Evaluating the Angina Plan in Patients Admitted to Hospital with Angina: A Randomized Controlled Trial. Cardiovascular Therapeutics. 2011,..."
#      },
#      {
#       "headline": "Morden JP, Lambert PC, Latimer N, Abrams KR, Wailoo AJ: Assessing methods for dealing with treatment switching in randomised controlled trials: a simulation study. BMC Med Res Methodol. 2011,..."
#      },
#      {
#       "headline": "White IR, Walker S, Babiker AG, Darbyshire JH: Impact of treatment changes on the interpretation of the Concorde trial. AIDS. 1997, 11 (8): 999-1006. 10.1097/00002030-199708000-00008."
#      },
#      {
#       "headline": "Borrelli B: The assessment, monitoring, and enhancement of treatment fidelity in public health clinical trials. J Public Health Dent. 2011, 71 (Suppl 1): S52-S63."
#      },
#      {
#       "headline": "Lawton J, Jenkins N, Darbyshire JL, Holman RR, Farmer AJ, Hallowell N: Challenges of maintaining research protocol fidelity in a clinical care setting: a qualitative study of the experiences..."
#      },
#      {
#       "headline": "Ye C, Giangregorio L, Holbrook A, Pullenayegum E, Goldsmith CH, Thabane L: Data withdrawal in randomized controlled trials: Defining the problem and proposing solutions: a commentary. Contemp..."
#      },
#      {
#       "headline": "Horwitz RI, Horwitz SM: Adherence to treatment and health outcomes. Arch Intern Med. 1993, 153 (16): 1863-1868. 10.1001/archinte.1993.00410160017001."
#      },
#      {
#       "headline": "Peduzzi P, Wittes J, Detre K, Holford T: Analysis as-randomized and the problem of non-adherence: an example from the Veterans Affairs Randomized Trial of Coronary Artery Bypass Surgery. Stat..."
#      },
#      {
#       "headline": "Montori VM, Guyatt GH: Intention-to-treat principle. CMAJ. 2001, 165 (10): 1339-1341."
#      },
#      {
#       "headline": "Gibaldi M, Sullivan S: Intention-to-treat analysis in randomized trials: who gets counted?. J Clin Pharmacol. 1997, 37 (8): 667-672. 10.1002/j.1552-4604.1997.tb04353.x."
#      },
#      {
#       "headline": "Porta M: A dictionary of epidemiology. 2008, Oxford: Oxford University Press, Inc, 5"
#      },
#      {
#       "headline": "Everitt B: Medical statistics from A to Z. 2006, Cambridge: Cambridge University Press, 2"
#      },
#      {
#       "headline": "Sainani KL: Making sense of intention-to-treat. PM R. 2010, 2 (3): 209-213. 10.1016/j.pmrj.2010.01.004."
#      },
#      {
#       "headline": "Bendtsen P, McCambridge J, Bendtsen M, Karlsson N, Nilsen P: Effectiveness of a proactive mail-based alcohol internet intervention for university students: dismantling the assessment and feedback..."
#      },
#      {
#       "headline": "Brox JI, Nygaard OP, Holm I, Keller A, Ingebrigtsen T, Reikeras O: Four-year follow-up of surgical versus non-surgical therapy for chronic low back pain. Ann Rheum Dis. 2010, 69 (9): 1643-1648...."
#      },
#      {
#       "headline": "McKnight PE, McKnight KM, Sidani S, Figueredo AJ: Missing Data: A Gentle Introduction. 2007, New York, NY: Guilford"
#      },
#      {
#       "headline": "Graham JW: Missing data analysis: making it work in the real world. Annu Rev Psychol. 2009, 60: 549-576. 10.1146/annurev.psych.58.110405.085530."
#      },
#      {
#       "headline": "Little RJ, D'Agostino R, Cohen ML, Dickersin K, Emerson SS, Farrar JT, Frangakis C, Hogan JW, Molenberghs G, Murphy SA, et al: The Prevention and Treatment of Missing Data in Clinical Trials...."
#      },
#      {
#       "headline": "Little RJA, Rubin DB: Statistical Analysis with Missing Data. 2002, New York NY: Wiley, 2"
#      },
#      {
#       "headline": "Rubin DB: Multiple Imputation for Nonresponse in Surveys. 1987, John Wiley & Sons, Inc: New York NY"
#      },
#      {
#       "headline": "Schafer JL: Analysis of Incomplete Multivariate Data. 1997, New York: Chapman and Hall"
#      },
#      {
#       "headline": "Son H, Friedmann E, Thomas SA: Application of pattern mixture models to address missing data in longitudinal data analysis using SPSS. Nursing research. 2012, 61 (3): 195-203. 10.1097/NNR.0b013e318..."
#      },
#      {
#       "headline": "Peters SA, Bots ML, den Ruijter HM, Palmer MK, Grobbee DE, Crouse JR, O'Leary DH, Evans GW, Raichlen JS, Moons KG, et al: Multiple imputation of missing repeated outcome measurements did not..."
#      },
#      {
#       "headline": "Zhang H, Paik MC: Handling missing responses in generalized linear mixed model without specifying missing mechanism. J Biopharm Stat. 2009, 19 (6): 1001-1017. 10.1080/10543400903242761."
#      },
#      {
#       "headline": "Chen HY, Gao S: Estimation of average treatment effect with incompletely observed longitudinal data: application to a smoking cessation study. Statistics in medicine. 2009, 28 (19): 2451-2472...."
#      },
#      {
#       "headline": "Ma J, Akhtar-Danesh N, Dolovich L, Thabane L: Imputation strategies for missing binary outcomes in cluster randomized trials. BMC Med Res Methodol. 2011, 11: 18-10.1186/1471-2288-11-18."
#      },
#      {
#       "headline": "Kingsley GH, Kowalczyk A, Taylor H, Ibrahim F, Packham JC, McHugh NJ, Mulherin DM, Kitas GD, Chakravarty K, Tom BD, et al: A randomized placebo-controlled trial of methotrexate in psoriatic..."
#      },
#      {
#       "headline": "de Pauw BE, Sable CA, Walsh TJ, Lupinacci RJ, Bourque MR, Wise BA, Nguyen BY, DiNubile MJ, Teppler H: Impact of alternate definitions of fever resolution on the composite endpoint in clinical..."
#      },
#      {
#       "headline": "A randomized, double-blind, futility clinical trial of creatine and minocycline in early Parkinson disease. Neurology. 2006, 66 (5)): 664-671.Google Scholar"
#      },
#      {
#       "headline": "Song P-K: Correlated Data Analysis: Modeling, Analytics and Applications. 2007, New York, NY: Springer Verlag"
#      },
#      {
#       "headline": "Pintilie M: Competing Risks: A Practical Perspective. 2006, New York, NY: John Wiley"
#      },
#      {
#       "headline": "Tai BC, Grundy R, Machin D: On the importance of accounting for competing risks in pediatric brain cancer: II. Regression modeling and sample size. Int J Radiat Oncol Biol Phys. 2011, 79 (4):..."
#      },
#      {
#       "headline": "Holbrook JT, Wise RA, Gold BD, Blake K, Brown ED, Castro M, Dozor AJ, Lima JJ, Mastronarde JG, Sockrider MM, et al: Lansoprazole for children with poorly controlled asthma: a randomized controlled..."
#      },
#      {
#       "headline": "Holbrook A, Thabane L, Keshavjee K, Dolovich L, Bernstein B, Chan D, Troyan S, Foster G, Gerstein H: Individualized electronic decision support and reminders to improve diabetes care in the..."
#      },
#      {
#       "headline": "Hilbe JM: Negative Binomial Regression. 2011, Cambridge: Cambridge University Press, 2"
#      },
#      {
#       "headline": "Forsblom C, Harjutsalo V, Thorn LM, Waden J, Tolonen N, Saraheimo M, Gordin D, Moran JL, Thomas MC, Groop PH: Competing-risk analysis of ESRD and death among patients with type 1 diabetes and..."
#      },
#      {
#       "headline": "Grams ME, Coresh J, Segev DL, Kucirka LM, Tighiouart H, Sarnak MJ: Vascular disease, ESRD, and death: interpreting competing risk analyses. Clin J Am Soc Nephrol. 2012, 7 (10): 1606-1614. 10.2215/C..."
#      },
#      {
#       "headline": "Lim HJ, Zhang X, Dyck R, Osgood N: Methods of competing risks analysis of end-stage renal disease and mortality among people with diabetes. BMC Med Res Methodol. 2010, 10: 97-10.1186/1471-2288-10-97."
#      },
#      {
#       "headline": "Chu R, Walter SD, Guyatt G, Devereaux PJ, Walsh M, Thorlund K, Thabane L: Assessment and implication of prognostic imbalance in randomized controlled trials with a binary outcome–a simulation..."
#      },
#      {
#       "headline": "Bowen A, Hesketh A, Patchick E, Young A, Davies L, Vail A, Long AF, Watkins C, Wilkinson M, Pearl G, et al: Effectiveness of enhanced communication therapy in the first four months after stroke..."
#      },
#      {
#       "headline": "Spiegelhalter DJ, Best NG, Lunn D, Thomas A: Bayesian Analysis using BUGS: A Practical Introduction. 2009, New York, NY: Chapman and Hall"
#      },
#      {
#       "headline": "Byers AL, Allore H, Gill TM, Peduzzi PN: Application of negative binomial modeling for discrete outcomes: a case study in aging research. J Clin Epidemiol. 2003, 56 (6): 559-564. 10.1016/S0895-4356..."
#      },
#      {
#       "headline": "Yusuf S, Wittes J, Probstfield J, Tyroler HA: Analysis and interpretation of treatment effects in subgroups of patients in randomized clinical trials. JAMA: the journal of the American Medical..."
#      },
#      {
#       "headline": "Altman DG: Better reporting of randomised controlled trials: the CONSORT statement. BMJ. 1996, 313 (7057): 570-571. 10.1136/bmj.313.7057.570."
#      },
#      {
#       "headline": "Mauskopf JA, Sullivan SD, Annemans L, Caro J, Mullins CD, Nuijten M, Orlewska E, Watkins J, Trueman P: Principles of good practice for budget impact analysis: report of the ISPOR Task Force..."
#      },
#      {
#       "headline": "The pre-publication history for this paper can be accessed here:http://www.biomedcentral.com/1471-2288/13/92/prepub"
#      }
#     ]
#    }
#   }
#  ]
# }

# %%
# Filter
# Convert text response from google api's into JSON
import json
json_response = json.loads(response.text)
json_response["context"]

# Filter searchTime and Total Results
json_response["searchInformation"]["searchTime"]

# Filter formattedUrl and htmlSnippet
# From all the items in the json_response

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re

for item in json_response["items"]:  
  url = item["formattedUrl"]
  html = item["htmlSnippet"]
  html = re.sub("<.*?>", "", html)
  html = re.sub("&nbsp", " ", html)
  wc = WordCloud().generate(html)
  print(url)
  plt.imshow(wc)
  #plt.title(url)
  plt.axis("off") 
  #plt.show()
# Out:
# https://en.wikipedia.org/wiki/Sensitivity_analysis
# https://www.investopedia.com/terms/s/sensitivityanalysis.asp
# https://corporatefinanceinstitute.com/.../what-is-sensitivity-analysis/
# https://www.edupristine.com/blog/all-about-sensitivity-analysis
# https://www.youtube.com/watch?v=56-iiZEjqnU
# https://www.sciencedirect.com/topics/medicine-and.../sensitivity-analysis
# https://docs.juliadiffeq.org/latest/analysis/sensitivity.html
# https://www.sciencedirect.com/topics/earth-and.../sensitivity-analysis
# https://www.ncbi.nlm.nih.gov/pubmed/27749700
# https://bmcmedresmethodol.biomedcentral.com/.../1471-2288-13-92

# %%
# Explore 

# Create a word cloud from the raw data coming from google
from wordcloud import WordCloud
tag_cloud = WordCloud().generate(response.text)

# Create an Image from the Tag Cloud
import matplotlib.pyplot as plt
plt.imshow(tag_cloud)
plt.axis("off")
plt.title("Word Cloud with Noise")
# Out:
# Text(0.5, 1.0, 'Word Cloud with Noise')
